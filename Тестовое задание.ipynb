# %% [markdown]
# # Вступление

# %% [markdown]
# Приветстуем вас на тестовом задании на вакансию аналитика данных в МТС Бизнес. В ходе этого задания мы пройдем основные этапы аналитики и работы с данными на примере датасета с информацией о пассажирах печально известного корабля "Титаник". Давайте начнем с загрузки самого датасета, который лежит __[здесь](https://www.kaggle.com/c/titanic/data?select=train.csv)__. Для скачивания нужно зарегистрироваться на сайте Kaggle и скачать файл, называемый train.csv. Он так же будет идти в архиве с этой тетрадкой, на случай если возникнут проблемы с сайтом

# %% [markdown]
# ## Шаг первый: прочитаем данные

# %% [markdown]
# Проимпортируем нужные библиотеки для работы с этим датасетом и прочитаем его. Использование других библиотек нежелательно, но возможно

# %%
import pandas as pd 
import numpy as np 

# Прочитаем csv файл в DataFrame из библиотеки pandas

# %% [markdown]
# <i>Если у вас выдает ошибку при запуске import'ов, то скорее всего эти библиотеки не установлены в вашей виртуальной среде </i>

# %% [markdown]
# Взгляните на описание столбцов, которые есть в нашей таблице. На случай, если у вас трудности в понимании проясним ключевые моменты:
# - Survival - обозначение, выжил ли пассажир после роковой поездки
# - pclass - класс, в котором был пассажир
# - Name - имя пассажира
# - sex - пол пассажира
# - Age - возраст пассажира
# - sibsp - количество братьев, сестер и супругов/супруг на борту
# - parch - количество родителей и детей на борту
# - ticket - номер билета
# - fare - цена за билет
# - cabin - номер кабины
# - embarked - порт, в котором пассажир сел на судно

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Теперь, когда мы разобрались с самими данными перейдем к задачам

# %% [markdown]
# ## Шаг второй: анализируем данные

# %% [markdown]
# <b>Задача: вывести пассажиров с менее чем двумя родственниками и старше 24 лет </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: посмотреть, какой процент пассажиров женского пола из первого класса выжило </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: Сколько в среднем стоил билет 2-го класса? </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: Сколько лет было самому молодому пассажиру мужского пола, который выжил? </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: Сколько было пассажиров в возрасте от 25 до 30 лет в третьем классе? </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: Сколько мужчин со словом John в имени было на судне? </b>

# %%
# Ваш код здесь

# %% [markdown]
# ## Шаг третий: работаем с пропусками

# %% [markdown]
# Начнем искать изъяны в наших данных и, естественно, их исправлять

# %% [markdown]
# <b>Задача: Сколько пропусков в столбце с возрастом?</b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: заполните пропуски в возрасте для мужчин средним возрастом мужчин на корабле, а для женщин - медианным возрастом женщин на корабле</b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: заполните пропуски в порту отправления наиболее часто встречающимся портом среди пассажиров</b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: удалите столбец cabin </b>

# %%
# Ваш код здесь

# %% [markdown]
# ## Шаг четвертый: дополняем данные

# %% [markdown]
# Добавим несколько новых столбцов в нашу таблицу

# %% [markdown]
# <b>Задача: замените буквенные обозначения портов в столбце Embarked на полные названия портов </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: разбейте пассажиров на 3 возрастные группы и создайте столбец, означающий к какой группе принадлежит пассажир (названия групп и их интервалы можете определить самостоятельно)</b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: создайте столбец, обозначающий, один ли человек путешествует (без родственников и супругов) </b>

# %%
# Ваш код здесь

# %% [markdown]
# <b>Задача: создайте столбец, содержащий инициалы пассажира (Mr. Mrs. и т.д.) </b>

# %%
# Ваш код здесь

# %% [markdown]
# ## Шаг пятый: отправить выполненные задания

# %% [markdown]
# Вот и все, все задания выполнены. На этом этапе вам предстоит отправить выполненное задание с результатами выполнения каждой ячейки кода. Спасибо за уделенное время и усилия над этими несложными задачками.

# %% [markdown]
# ![image.png](attachment:image.png)
